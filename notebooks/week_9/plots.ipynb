# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_losses = np.load('pre-train.npy')

# %%
plt.figure(figsize=(12, 8))
plt.plot(list(range(1, 21)), plot_losses[:, 1], '--b')
# plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
plt.plot(list(range(1, 21)), plot_losses[:, 2], '--r')

plt.xticks(list(range(1, 21)))
# plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
# plt.plot(plot_losses[:,0], random_acc[:50], '.-g')
# plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
# plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    'Training Loss',
    # 'Training Overall pixel accuracy',
    'Validation Loss',
    # 'Validation Overall pixel accuracy',
    # 'Random pixel accuracy',
    # 'Validation PerClass accuracy',
    # 'Validation Jaccard index']
], fontsize=20)  # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('pre-train.svg', format='svg')
plt.show()

# %%
plot_losses = np.load('train.npy')

# %%
plt.figure(figsize=(12, 8))
plt.plot(plot_losses[:,0], plot_losses[:,1], '--b')
plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
plt.plot(plot_losses[:,0], plot_losses[:,3], '--r')
plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    'Training Loss',
    'Training Overall pixel accuracy',
    'Validation Loss',
    'Validation Overall pixel accuracy',
    'Validation PerClass accuracy',
    'Validation Jaccard index'
], fontsize=20)  # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('train.svg', format='svg')
plt.show()

# %%
val_overall_pixel_acc = plot_losses[:,5]
val_per_class_acc = plot_losses[:,6]
val_jaccard = plot_losses[:,7]

# %%
ix = 21
print(val_overall_pixel_acc[ix], val_per_class_acc[ix], val_jaccard[ix])
# Out:
# 0.7862880825996399 0.5634775757789612 0.4450218379497528

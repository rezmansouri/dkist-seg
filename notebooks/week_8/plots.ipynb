# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_losses = np.load('att.npy')

# %%
plt.figure(figsize=(12,8))
# plt.plot(plot_losses[:,0], plot_losses[:,1], '--b')
plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
# plt.plot(plot_losses[:,0], plot_losses[:,3], '--r')
plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
# plt.plot(plot_losses[:,0], random_acc[:50], '.-g')
plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    # 'Training Loss', 
            'Training Overall pixel accuracy', 
            # 'Validation Loss',
            'Validation Overall pixel accuracy', 
            # 'Random pixel accuracy', 
            'Validation PerClass accuracy',
            'Validation Jaccard index'], fontsize=20) # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('att_acc.svg', format='svg')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(plot_losses[:,0], plot_losses[:,1], '--b')
# plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
plt.plot(plot_losses[:,0], plot_losses[:,3], '--r')
# plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
# plt.plot(plot_losses[:,0], random_acc[:50], '.-g')
# plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
# plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    'Training Loss', 
            # 'Training Overall pixel accuracy', 
            'Validation Loss',
            # 'Validation Overall pixel accuracy', 
            # 'Random pixel accuracy', 
            # 'Validation PerClass accuracy',
            # 'Validation Jaccard index'
            ], fontsize=20) # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('att_loss.svg', format='svg')
plt.show()

# %%
plot_losses = np.load('r2.npy')

# %%
plt.figure(figsize=(12,8))
# plt.plot(plot_losses[:,0], plot_losses[:,1], '--b')
plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
# plt.plot(plot_losses[:,0], plot_losses[:,3], '--r')
plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
# plt.plot(plot_losses[:,0], random_acc[:50], '.-g')
plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    # 'Training Loss', 
            'Training Overall pixel accuracy', 
            # 'Validation Loss',
            'Validation Overall pixel accuracy', 
            # 'Random pixel accuracy', 
            'Validation PerClass accuracy',
            'Validation Jaccard index'], fontsize=20) # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('r2_acc.svg', format='svg')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(plot_losses[:,0], plot_losses[:,1], '--b')
# plt.plot(plot_losses[:,0], plot_losses[:,2], '.-b')
plt.plot(plot_losses[:,0], plot_losses[:,3], '--r')
# plt.plot(plot_losses[:,0], plot_losses[:,5], '.-r')
# plt.plot(plot_losses[:,0], random_acc[:50], '.-g')
# plt.plot(plot_losses[:,0], plot_losses[:,6], color='tab:green')
# plt.plot(plot_losses[:,0], plot_losses[:,7], color='tab:orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.ylim(0.7, 1)
# plt.xlim(0.0, 50.0)
plt.grid()
plt.legend([
    'Training Loss', 
            # 'Training Overall pixel accuracy', 
            'Validation Loss',
            # 'Validation Overall pixel accuracy', 
            # 'Random pixel accuracy', 
            # 'Validation PerClass accuracy',
            # 'Validation Jaccard index'
            ], fontsize=20) # using a named size
# plt.title('SegNet - ImaX/Sunrise Focal loss')
plt.tight_layout()
plt.savefig('r2_loss.svg', format='svg')
plt.show()
